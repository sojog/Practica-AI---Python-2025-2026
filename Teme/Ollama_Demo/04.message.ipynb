# %%
exemplu_mesaj_user = {'role': 'user', 'content': 'Explica-mi in limba romana ce este Django in Python'}

# %%
exemplu_mesaj_gpt = {'role': 'assistant', 'content': '....RASPUNSUL EFECTIV....'}

# %%
lista_mesaje = [  {'role': 'user', 'content': 'Explica-mi in limba romana ce este Django in Python'}, 
                  {'role': 'assistant', 'content': '....RASPUNSUL EFECTIV....'} ]
