# %% [markdown]
# # ! pip install requests

# %%
import requests

# %%
BASE_URL = "http://localhost:11434"

# %%
VERSION_PATH =  BASE_URL + "/api/version"

# %%
response = requests.get(VERSION_PATH)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'version': '0.13.1'}
