# %%
from ollama import Ollama

# %%
gpt = Ollama()

# %%
gpt.available_models
# Out:
# ['gemma3:latest', 'qwen2.5-coder:14b', 'gemma3:270m']

# %%
gpt.current_model
# Out:
# 'gemma3:latest'

# %%
gpt.current_model = 'qwen2.5-coder:14b'

# %%
gpt.current_model
# Out:
# 'qwen2.5-coder:14b'

# %%
gpt.current_model = 0

# %%
gpt.current_model
# Out:
# 'gemma3:latest'

# %%
gpt.ask()
# Out:
# '**IoT (Internet of Things) - sau Internetul Lucrurilor - se referă la rețeaua de dispozitive fizice (obiecte, vehicule, aparate electrocasnice etc.) care sunt integrate cu senzori, software și internet, permițându-le să colecteze și să schimbe date.**\n\n**Mai simplu, IoT înseamnă conectarea obiectelor obișnuite la internet, astfel încât să poată comunica între ele și cu noi.**\n\n**Iată o descompunere a elementelor cheie ale definiției:**\n\n* **Dispozitive Fizice (Lucruri):** Acestea pot fi orice, de la termostate și ceasuri inteligente până la mașini industriale și echipamente medicale.\n* **Senzori:** Dispozitivele IoT utilizează senzori pentru a colecta date din mediul înconjurător (temperatură, umiditate, mișcare, etc.).\n* **Software:** Software-ul gestionează datele colectate, permite dispozitivelor să comunice și permite dezvoltarea de aplicații și servicii bazate pe date.\n* **Internet:** Internetul este canalul prin care datele sunt transmise și procesate.\n* **Comunicare
# ...
