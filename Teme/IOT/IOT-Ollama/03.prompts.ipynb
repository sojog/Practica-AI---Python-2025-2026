# %%
from ollama import Ollama

gpt = Ollama()
print(gpt)
# Out:
# Current model gemma3:latest. You can choose from gemma3:latest, qwen2.5-coder:14b, gemma3:270m

# %%
gpt.current_model = 1

# %%
PROMPT = "Am nevoie de o lista de cumparaturi de alimente consumate saptamanal care sunt bune pentru sanatate/longevitate etc. Lista vreau sa fie pentru o familie de 2, as vrea sa incluzi acolo avocado, produse de peste, afine etc."

gpt.ask(PROMPT)
# Out:
# 'Iată o listă de cumpărături săptămânale pentru o familie de 2 persoane, concentrându-vă pe alimente bune pentru sănătate și longevity:\n\n1. **Proteine:**\n   - 2-3 pachete de carne grăsimată redusă (morcov, porc, polonez)\n   - 4-5 kilograme de carne blândă (pui, vitel, ton la schimbare)\n   - 1-2 fileturi de peste\n   - 1-2 cutii de ouă\n   - 2-3 boabe de friptură sau friptură\n\n2. **Alimente sănătoase:**\n   - 5-6 kilograme de legume (arugula, spinat, broccoli, fasole verde)\n   - 4-5 kilograme de fructe (morcovi, ceai, mere, pere)\n   - 2-3 kilograme de porumb\n   - 1-2 kilograme de făină integrală sau integrată\n\n3. **Alimente integrale:**\n   - 500g de ovăz sau gârlăbușii (cereale integrale)\n   - 400g de quinoa\n   - 200g de arahide și măsline\n   - 1-2 boabe de fasole\n\n4. **Alimente pentru sănătate:**\n   - 5-6 avocado-uri pe săptămână\n   - 1-2 kilograme de zahărătă (banane, grâu, kiwi)\n   - 500g de ceai verde sau roșu\n\n5. **Alimente pentru întreaga familie:**\n   - 2-3 kilograme de brânză sau mozzarella\n   - 1-2 kilograme de mămăligă (integrală sau neagră)\n   - 500g de focaccia sau piteșoare\n\n6. **Alimente pentru boli:**\n   - 1-2 boabe de ouă\n   - 1-2 boabe de ceai\n   - 500g de pâine integrală\n\n7. **Condimente și aditivi sănătoase:**\n   - Oțet de usturoi sau sare verde\n   - Usturoi sau condimente sănătoase\n   - 500g de măsline verzi\n   - 2-3 cutii de oregano sau basilic\n\nAceastă listă vă oferă o varietate de alimente care sunt bogate în proteine, fibre, antioxidanți și alte nutrienți esențiali pentru sănătatea generală. Dacă aveți nevoie de ajustări sau preferințe specifice, nu ezitați să le adăugați sau să le scoateți.'

# %%
PROMPT = "Am nevoie de o lista de cumparaturi de alimente consumate saptamanal care sunt bune pentru sanatate/longevitate etc. Lista vreau sa fie pentru o familie de 2, as vrea sa incluzi acolo avocado, produse de peste, afine etc. Incearca sa nu il faci foarte focusat pe colesterol"
response = gpt.ask(PROMPT)
print(response)
# Out:
# Sigur, iată o listă de cumpărături săptămânale pentru o familie de 2 persoane care se concentrează pe alimente sănătoase și benefice pentru longevitate:
#
# 1. Fructe:
#    - Morcovi
#    - Portocale
#    - Ananas
#    - Banane
#    - Mere
#
# 2. Legume:
#    - Conopști
#    - Broccoli
#    - Mușețel
#    - Ardei
#    - Spinach
#
# 3. Alimente grase sănătoase:
#    - Avocado
#    - Nuci (amandoule, nuci de pahar)
#    - Castanete
#
# 4. Proteine:
#    - Peste gras (salamon, marelus)
#    - Iaurt grec cu nuci
#    - Orez integral
#    - Făină integrală pentru pizza sau pasta
#
# 5. Cereale:
#    - Porumb
#    - Suplimente de grâu complet (daca nu se consumă suficient porumb)
#
# 6. Afine și legume proaspate:
#    - Zâmbetel
#    - Măsline verzi (ca în salads sau ca condiment)
#    - Varză verde
#
# 7. Alimente integrale:
#    - Chiflă integrală
#    - Biscuițe fără gluten de pahar
#
# 8. Bere și apă minerală
# 9. Ouat integral pentru panificare
# 10. Hummus sau alte spread-uri sănătoase
# 11. Alimente în conservă (peste, legume) pentru zilele ocupate
#
# Această listă include o gamă de alimente sănătoase care oferă proteine, fibre, antioxidanți și grase omogene pentru a menține organismul sănătos. Deși avocado conține grăsimi saturate, este important să consumeți cantități moderare ca parte a unei dieete echilibrate.
#
# Acesta nu este un plan alimentar prescris, dar oferă idei despre cum puteți începe să vă construiți o dietă care să fie beneficiată pentru health.

# %%
DESCRIPTION = """ ```The IoT is a term used to describe the interconnected network of physical devices,
vehicles, home appliances, and other items embedded with electronics, software,
sensors, and connectivity which enables these objects to connect and exchange data
with each other. The concept of the IoT can be traced back to the late 1990s and
early 2000s, when researchers and technology experts first started exploring the idea
of connecting everyday devices to the internet [1, 2]. One of the earliest examples
of IoT technology was a Coca-Cola machine at Carnegie Mellon University, which
was connected to the internet in 1982 and allowed users to check the availability of
drinks remotely [34]. Over the next few years, the development of wireless networks,
advancements in miniaturization, and the growth of the internet paved the way for
the development of the IoT. In 1999, Kevin Ashton, a British technology pioneer,
coined the term “IoT” to describe the interconnected network of devices and objects
[35]. In the early 2000s, the IoT began to gain momentum, with the introduction of
smartphones and the growth of home automation systems. In 2006, Amazon intro-
duced the Amazon Echo, a smart speaker that uses voice commands to control smart
home devices and access information from the internet [36]. Since then, the IoT has
continued to grow and evolve, with an increasing number of devices being connected
to the internet. Today, the IoT is being used in a wide range of applications, from
smart homes and cities to industrial systems and healthcare. Figure 1.4 gives insight
into the history of the IoT, showing how the term IoT has evolved in the technological
world over the period of last three decades. LG announced the first smart refrigerator in 2000, the first iPhone was launched
in 2007, and by 2008, the number of connected devices exceeded the number of
people on the planet [2, 31]. In 2009, Google started testing driverless cars, and in
2011, Google’s Nest smart thermostat hit the market, allowing remote control of cen-
tral heating and cooling. The concept of IoT started to gain some popularity in the
summer of 2010. Information leaked that Google’s StreetView service had not only
made 360-degree pictures but had also stored tons of data of people’s Wi-Fi networks
[37]. People were debating whether this was the start of a new Google strategy to not
only index the internet but also index the physical world. The same year, the Chinese
government announced it would make the IoT a strategic priority in its updated Five-
Year Plan. In 2011, Gartner—the market research company that invented the famous
“hype-cycle for emerging technologies”—included a new emerging phenomenon on
its list: “The Internet of Things” [6]. The next year, the theme of Europe’s biggest
internet conference LeWeb was the “Internet of Things.” At the same time, popular
tech-focused magazines like Forbes, Fast Company, and Wired starting using IoT as
their vocabulary to describe the phenomenon. In October of 2013, IDC published a
report stating that the IoT would be a $8.9 trillion market in 2020 [17]. The term IoT
reached mass market awareness when in January 2014, Google announced the pur-
chase of Nest for US$3.2 billion. At the same time, the Consumer Electronics Show
(CES) in Las Vegas was held under the theme of IoT. Despite its tremendous growth,
the IoT is still in its early stages and is expected to continue to evolve and grow in the
coming years, with the development of new technologies and increasing demand for
connected devices.```"""


PROMPT = f"""Ai urmatoarea descrierea de mai jos. Task-ul tau este sa rezumi pe ani toata istoria IOT.

Exemplu:
1989 - Primul device IOT creat
1993 - camera webcam folosita in Cambridge


{DESCRIPTION} """

response = gpt.ask(PROMPT)
print(response)
# Out:
# Iată o reprezentare pe ani a istoriei IoT:
#
# 1982 - Primul dispozitiv IoT creat (Coca-Cola machine la Carnegie Mellon University)
# 1993 - Apariția primei camere web în Cambridge
# 1999 - Kevin Ashton introduce termenul "IoT"
# 2000 - Primul frigider inteligent (LG)
# 2006 - Amazon Echo, primul asistent vocal inteligent
# 2007 - Lansarea iPhone-ului
# 2008 - Numărul de dispozitive conectate depășește numărul de oameni din lume
# 2009 - Google începe testările mașinilor autonome
# 2011 - Apariția termostatului inteligent Nest Google
# 2013 - IDC prezintă raport cu proiecții privind marja IoT până în 2020
# 2014 - Anul IoT, cumpărarea Google a lui Nest pentru $3.2 miliarde
#
# Această cronologie evidențiază principalele evenimente și milepstone-urile din dezvoltarea IoT de la început până în anii 2010.

# %%
PROMPT = """ Ai urmatoarele caracteristici ideale ale unor device-uri IOT. Pentru fiecare da-mi o explicatie de cateva cuvinte (maxim 7). 

Exemplu:
Ubicu - fara interfata sau interfata implicita

```Ubicuu, Smart, Agile, On demand, Blend into background, Secure, Low maintenance, Fast, Upgradable, Growing, Adaptable```"""
response = gpt.ask(PROMPT)
print(response)
# Out:
# 1. Ubicuu: Fără interfata sau interfata implicita
# 2. Smart: Inteligent, autonom, capabil să învețe și să adapteze comportamentul.
# 3. Agile: Flexibil, rapid în adaptarea la schimbări și implementarea actualizărilor.
# 4. On demand: Disponibil pe cerere, oferind servicii sau resurse când sunt necesare.
# 5. Blend into background: Integrat în mediul de viață cotidian fără a distra.
# 6. Secure: Sigur, protejând datele și funcțiile esențiale împotriva amenințărilor digitale.
# 7. Low maintenance: Ușor de întreținut sau cu necesitate minimă de serviciu și actualizare.
# 8. Fast: Rapid în procesarea informației și în executarea acțiunilor solicitate.
# 9. Upgradable: Posibilitatea de actualizare a software-ului și hardware-ului pentru îmbunătățirea performanței.
# 10. Growing: Capacitate de dezvoltare continuă, încreștere a funcțiilor și abilităților.
# 11. Adaptable: Capabil să se ajusteze la noi condiții sau tipuri de utilizare.
